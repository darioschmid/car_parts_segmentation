# %% [markdown]
# #Running the pipeline in colab

# %%
# !git clone https://github.com/darioschmid/dl_car_segmentation.git
# Out:
# Cloning into 'dl_car_segmentation'...
# remote: Enumerating objects: 260, done.
# remote: Counting objects: 100% (260/260), done.
# remote: Compressing objects: 100% (174/174), done.
# remote: Total 260 (delta 126), reused 199 (delta 74), pack-reused 0
# Receiving objects: 100% (260/260), 4.37 MiB | 14.21 MiB/s, done.
# Resolving deltas: 100% (126/126), done.

# %%
from google.colab import drive
drive.mount('/content/dl_car_segmentation/drive')
# Out:
# Mounted at /content/dl_car_segmentation/drive

# %%
data_dir = 'MyDrive/Colab Notebooks/car_segmentation/carseg_data_new/arrays/'
# !ls drive/'MyDrive/Colab Notebooks/car_segmentation/carseg_data_new/'
# Out:
# ls: cannot access 'drive/MyDrive/Colab Notebooks/car_segmentation/carseg_data_new/': No such file or directory

# %%
# %cd dl_car_segmentation/
# Out:
# /content/dl_car_segmentation

# %%
# %%writefile config.json
# {
#     "name": "Mini",
#     "n_gpu": 1,
#     "train_pictures": 0,
#
#     "arch": {
#         "type": "MiniPix2PixModel",
#         "args": {
#             "gf_dim": 64,
#             "df_dim": 64,
#             "c_dim": 3
#         }
#     },
#     "data_loader": {
#         "type": "CarsDataLoader",
#         "args":{
#             "data_dir": "./test_data/",
#             "batch_size": 4,
#             "shuffle": true,
#             "validation_split": 0.1,
#             "num_workers": 2
#         }
#     },
#     "optimizer": {
#         "type": "Adam",
#         "resume": false,
#         "args":{
#             "lr": 0.0001,
#             "weight_decay": 0,
#             "amsgrad": true
#         }
#     },
#     "loss": "BCE_loss",
#     "metrics": [
#         "accuracy"
#     ],
#     "lr_scheduler": {
#         "type": "StepLR",
#         "args": {
#             "step_size": 250,
#             "gamma": 0.1
#         }
#     },
#     "trainer": {
#         "type": "GAN",
#         "epochs": 150,
#
#         "save_dir": "saved/",
#         "save_period": 50,
#         "verbosity": 2,
#
#         "monitor": "min val_loss",
#         "early_stop": 10,
#
#         "tensorboard": true
#     }
# }
# Out:
# Overwriting config.json

# %%
# !python train.py --config config.json
# Out:
# MiniPix2PixModel(
#   (G): MiniPix2PixGenerator(
#     (e1): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     )
#     (e2): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (e3): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (e4): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     )
#     (d1): Sequential(
#       (0): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (d2): Sequential(
# ...

# %%
# !python3 -m tensorboard.main --logdir=saved/log/Test/
# Out:
# 2023-11-13 13:55:23.777894: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-13 13:55:23.777952: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-13 13:55:23.777987: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-13 13:55:23.786023: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
